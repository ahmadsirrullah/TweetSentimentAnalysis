# %%
import twint
import pandas as pd

# %%
# Configure
c = twint.Config()

# Keyword = bule bali berulah, ulah bule bali, kampung bule bali, polah bule bali, bule bali helm,
#           usaha bule bali,Bule langgar aturan, Bule nakal, Bule ganggu, Bule bangsat, Bule goblok, Bule kere, Bule ngemis
#           Gentrifikasi bali, Bule bule bali

c.Search = 'Bule bule bali'
c.Store_csv = True
c.Output = 'coba15.csv'
c.Since = '2022-01-01'
c.Until = '2023-04-03'
c.Limit = 5000
#c.Format = 'ID {id} | Username {username} | Tweets {tweets} | Url {url}'

# Run
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-45082f833c62> in <module>
#      15
#      16 # Run
# ---> 17 twint.run.Search(c)
#
# e:\jointsugm_ds\twint\src\twint\twint\run.py in Search(config, callback)
#     408     config.Followers = False
#     409     config.Profile = False
# --> 410     run(config, callback)
#     411     if config.Pandas_au:
#     412         storage.panda._autoget("tweet")
#
# e:\jointsugm_ds\twint\src\twint\twint\run.py in run(config, callback)
#     327         raise
#     328
# --> 329     get_event_loop().run_until_complete(Twint(config).main(callback))
#     330
#     331
#
# ~\anaconda3\envs\tweet_mining\lib\asyncio\base_events.py in run_until_complete(self, future)
#     473         future.add_done_callback(_run_until_complete_cb)
#     474         try:
# --> 475             self.run_forever()
#     476         except:
# ...

# %%
coba = pd.read_csv('coba.csv')
coba2 = pd.read_csv('coba2.csv')
coba3 = pd.read_csv('coba3.csv')
coba4 = pd.read_csv('coba4.csv')
#coba5 = pd.read_csv('coba5.csv')
coba6 = pd.read_csv('coba6.csv')
coba7 = pd.read_csv('coba7.csv')
coba8 = pd.read_csv('coba8.csv')
coba9 = pd.read_csv('coba9.csv')
coba10 = pd.read_csv('coba10.csv')
coba11 = pd.read_csv('coba11.csv')
coba12 = pd.read_csv('coba12.csv')
coba13 = pd.read_csv('coba13.csv')
coba14 = pd.read_csv('coba14.csv')
coba15 = pd.read_csv('coba15.csv')

# %%
coba_append = coba_append.append(coba15)
coba_append
# Out:
#                      id      conversation_id  \
# 0   1641032074587979777  1641031093297004546
# 1   1640601848502525953  1640601848502525953
# 2   1640566457309470720  1640566457309470720
# 3   1640220806062960644  1640220806062960644
# 0   1642124921710198785  1641649781528469505
# ..                  ...                  ...
# 18  1640424397675823104  1640247688624209920
# 19  1640343299096707073  1640314758212771840
# 20  1640198194515570688  1640198194515570688
# 21  1640186577933713408  1640186577933713408
# 22  1639958649673224192  1639958649673224192
#
#                                    created_at        date      time  timezone  \
# 0   2023-03-29 17:58:30 SE Asia Standard Time  2023-03-29  17:58:30       700
# 1   2023-03-28 13:28:56 SE Asia Standard Time  2023-03-28  13:28:56       700
# 2   2023-03-28 11:08:18 SE Asia Standard Time  2023-03-28  11:08:18       700
# 3   2023-03-27 12:14:48 SE Asia Standard Time  2023-03-27  12:14:48       700
# ...

# %%
coba_append.axes[1]
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
coba_append_cp = coba_append.copy()
coba_append_cp = coba_append_cp.drop(columns = ['conversation_id', 'created_at', 'timezone', 'place', 'photos', 'replies_count', 'retweets_count', 'likes_count','retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src'])

# %%
coba_append_cp.axes[1]
# Out:
# Index(['id', 'date', 'time', 'user_id', 'username', 'name', 'tweet',
#        'language', 'mentions', 'urls', 'hashtags', 'cashtags', 'link',
#        'retweet', 'quote_url', 'video', 'thumbnail', 'near', 'geo', 'source',
#        'user_rt_id', 'user_rt', 'trans_dest'],
#       dtype='object')

# %%
coba_append_cp['user_rt_id']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 0    NaN
#       ..
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# Name: user_rt_id, Length: 549, dtype: float64

# %%
coba_append_cp = coba_append_cp.drop(columns =['hashtags', 'cashtags', 'trans_dest', 'video', 'thumbnail', 'near', 'geo','source','user_rt_id', 'user_rt'])

# %%
coba_append_cp.axes[1]
# Out:
# Index(['id', 'date', 'time', 'user_id', 'username', 'name', 'tweet',
#        'language', 'mentions', 'urls', 'link', 'retweet', 'quote_url'],
#       dtype='object')

# %%
coba_append_cp = coba_append_cp.drop(columns = ['retweet', 'quote_url', 'mentions', 'urls'])

# %%
coba_append_cp = coba_append_cp.reset_index().drop(columns = 'index')

# %%
coba_append_cp[coba_append_cp['language'] != 'in'].shape
# Out:
# (13, 9)

# %%
coba_append_cp.duplicated().sum()
# Out:
# 10

# %%
coba_append_cp.to_csv('tweet_bule_bali.csv')
